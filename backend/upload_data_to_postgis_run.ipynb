# %%
from postgis_functions import get_pg_connection, upload_csv_to_postgis, upload_gpkg

dbname = 'geog293_map2'
get_pg_connection(dbname)
# Out:
# 'postgresql://postgres:hdperez@localhost:5432/geog293_map2'

# %%
csv_path = r"C:\Users\Ham\Documents\01 - MS Geomatics\07 - Geog 293 (Elective)\03 - Map Projects\Map2_WebAppResume\data\places.csv"
pg_table_name = 'places'
upload_csv_to_postgis(csv_path, pg_table_name, dbname)
# Out:
# 📦 Loaded CSV with 6 records and 9 columns.
# ✅ Uploaded to PostgreSQL table 'places'

# %%
gpkg_path = r"C:\Users\Ham\Documents\01 - MS Geomatics\05 - GmE 210\3-Project\01_Data\LST\LST_Celsius_041025_WGS84_points.gpkg"
layer_name = 'qc_lst_points'
upload_gpkg(gpkg_path, layer_name, dbname)
# Out:
# ✅ Uploaded qc_lst_points to table!
